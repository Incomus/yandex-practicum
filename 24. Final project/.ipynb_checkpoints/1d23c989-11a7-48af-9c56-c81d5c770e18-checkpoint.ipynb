# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий тимлида</b>
#
#
# Привет, Глеб!
#
# Это Дмитрий, и мы вместе будем работать над финальным проектом.
#
#
# Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
# Как и в остальных спринтах, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе  вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
#
# Как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - план v1 </b>
# На вводном совещании я заострил внимание, что проект должен начинаться с названия и описания.</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#
# Добавил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v2 </b>
# 👍 </div>

# %% [markdown]
# # Проект: промышленность
# Чтобы оптимизировать производственные расходы, металлургический комбинат ООО «Так закаляем сталь» решил уменьшить потребление электроэнергии на этапе обработки стали. Необходимо построить модель, которая предскажет температуру стали.
#
# Данные состоят из файлов, полученных из разных источников:
#
#     data_arc_new.csv — данные об электродах;
#     data_bulk_new.csv — данные о подаче сыпучих материалов (объём);
#     data_bulk_time_new.csv — данные о подаче сыпучих материалов (время);
#     data_gas_new.csv — данные о продувке сплава газом;
#     data_temp_new.csv — результаты измерения температуры;
#     data_wire_new.csv — данные о проволочных материалах (объём);
#     data_wire_time_new.csv — данные о проволочных материалах (время).
#
# Будут построены предсказательные модели на основе нейронных сетей. Лучшая модель будет применима для предсказания технологического параметра.

# %% [markdown]
# # Цель работы
# Построение модели для предсказания характеристики технологического процесса, конечной температуры стали в ковше, по заданным параметрам процесса.

# %% [markdown]
# # План работы
# 1. Исследование данных
# 2. Предподготовка данных, свод данных в одну таблицу для дальнейшего использования моделью
# 3. Разбиение данных на тестовую и обучающую выборки. Построение моделей и выбор лучшей проверкой на тестовой выборке.
# 4. Написание отчета

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# По плану ОК
#
#
# Дополнительные советы:
#
# Пропуски в данных по сыпучим продуктам и проволоке можно заполнить нулями.
#
# При объединении данных по ключу используем inner_jon (т.е. берем только те партии, где есть все данные)
#
# После получения итогового датафрейма с признаками нужно провести его исследование (включая построение графиков для признаков).
#
# Перед обучением моделей стоит исследовать взаимную кореляцию признаков.
#
# Советую добавить  анализ важности признаков модели-победителя и проверку модели на адекватность с помощью константной модели.
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
from catboost import CatBoostRegressor

STATE = 140823

# %% [markdown]
# ## Исследование данных

# %%
data_arc = pd.read_csv('/datasets/data_arc_new.csv')
data_bulk = pd.read_csv('/datasets/data_bulk_new.csv')
data_bulk_time = pd.read_csv('/datasets/data_bulk_time_new.csv')
data_gas = pd.read_csv('/datasets/data_gas_new.csv')
data_temp = pd.read_csv('/datasets/data_temp_new.csv')
data_wire = pd.read_csv('/datasets/data_wire_new.csv')
data_wire_time = pd.read_csv('/datasets/data_wire_time_new.csv')

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# ОК, данные загружены и готовы к работе </div>

# %% [markdown]
# ### Данные об электродах

# %%
data_arc.info()
data_arc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
#  2   Конец нагрева дугой   14876 non-null  object
#  3   Активная мощность     14876 non-null  float64
#  4   Реактивная мощность   14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    Реактивная мощность
# ...

# %% [markdown]
# Так как имеем возможность использовать данные об электродах по ходу процесса, можем рассчитать общую затраченную энергию на каждую партию, просуммировав её для каждого ключа, через затраченное время и полную мощность. Пропусков нет, проблем нет

# %%
print('Всего строк:', data_arc['key'].count())
print('Всего ключей:', data_arc['key'].value_counts().count())

sns.histplot(x=data_arc['key'].value_counts(), bins=data_arc['key'].value_counts().max())
plt.xlabel('Число записей в ключе')
plt.ylabel('Число ключей')
plt.title('Разбивка ключей по числу записей электродов');
# Out:
# Всего строк: 14876
# Всего ключей: 3214

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - план v1 </b>
#
# Не стоит "печатать" датафреймы через print (а data_arc['key'].value_counts().describe()- это датафрейм)
#
# Не каждому читателю будет понятно, что интересного ты нашел в этой табличке (data_arc['key'].value_counts().describe()), стоит дать пояснение.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - план v1 </b>
#
# Этот и следующий комментарий я не буду дублировать, но пожалуйста исправь ВО ВСЕМ ПРОЕКТЕ
#
# <HR>
#
# Напоминаю, что по правилам оформления проектов у графиков должны быть названия и подписаны оси (где это уместно).</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Прошу избавиться от вывода текстового представления python-объектов, которые возвращают используемые тобой функции например
#
#     <AxesSubplot:xlabel='real_age'>
#
# или
#
#     Text(0.5, 0, 'Возраст')
#
# Это можно сделать достаточно просто, если добавить  точку с запятой после последней команды в ячейке
#
#
#   </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#
# Изменил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v2 </b>
# 👍 </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>минутка теории</b>
#  По умолчанию jupyter notebook выводит результат вычислений в последней строке ячейки, если этот результат не записан в переменную. Мы часто пользуемся этим, обратившись к какому-нибудь объекту в последней строке и видим результат без дополнительных print() или dispay()
#
#
#   Ниже три ячейки с кодом. Обрати внимание, если просто сделать вычисление - то результат выводится, но если добавить точку с запятой или записать результат в переменную, то ничего не происходит. Обрати внимание, когда происходит вывод:
#    - последня строка
#    - нет точки с запятой в конце
#
#    - результат не записан в переменную
#
# И досточно убрать одно из этих условий, как вывода нет.
#
# ![image-4.png](attachment:image-4.png)
#
#  Функции matlitlib не только выводят графики, но и возвращают python объекты axis. Это внутренняя кухня, чтобы можно было строить сложные графики. Но для нас побочным эффектом является то, что в ноутбуке мы видим текстовое предоставление объекта, которое выводит ноутбук. И для красоты такое поведение стоит заблокировать.
#
#
#
# </div>

# %%
data_arc['Активная мощность'].describe()
# Out:
# count    14876.000000
# mean         0.662752
# std          0.258885
# min          0.223120
# 25%          0.467115
# 50%          0.599587
# 75%          0.830070
# max          1.463773
# Name: Активная мощность, dtype: float64

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(x=data_arc['Активная мощность'], ax=ax_box)
sns.histplot(x=data_arc['Активная мощность'], ax=ax_hist)
plt.ylabel('Число записей')
ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True);

# %% [markdown]
# Наблюдается стандартное отклонение

# %%
data_arc['Реактивная мощность'].describe()
# Out:
# count    14876.000000
# mean         0.438986
# std          5.873485
# min       -715.479924
# 25%          0.337175
# 50%          0.441639
# 75%          0.608201
# max          1.270284
# Name: Реактивная мощность, dtype: float64

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(x=data_arc['Реактивная мощность'][data_arc['Реактивная мощность'] > -10], ax=ax_box)
sns.histplot(x=data_arc['Реактивная мощность'][data_arc['Реактивная мощность'] > -10], ax=ax_hist)
plt.ylabel('Число записей')
ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True);

# %% [markdown]
# Есть ошибки в полученных данных для реактивной мощности. Их немного, эти партии можно удалить

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - план v1 </b>
#
# На вводном созвоне я говорил, что этот проект не про временные ряды. Да, ты вывел график, но его читаемость очень низка. Да мы можем заметить, что значения лежат между 0,2 и 1,2, есть выброс "вниз" и был перерыв (видимо отпуск).
#
# Но эту же информацию, более наглядно ты можешь увидеть если построишь гистограмму + боксплот. При этом гистограмма хорошо покажет само распределение, а боксплот выбросы.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#
# Изменил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v2 </b>
# 👍
#
#
# </div>

# %% [markdown]
# ### Данные о подаче сыпучих материалов (объём)

# %%
data_bulk.info()
data_bulk.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    float64
#  2   Bulk 2   22 non-null     float64
#  3   Bulk 3   1298 non-null   float64
#  4   Bulk 4   1014 non-null   float64
#  5   Bulk 5   77 non-null     float64
#  6   Bulk 6   576 non-null    float64
#  7   Bulk 7   25 non-null     float64
#  8   Bulk 8   1 non-null      float64
#  9   Bulk 9   19 non-null     float64
#  10  Bulk 10  176 non-null    float64
#  11  Bulk 11  177 non-null    float64
#  12  Bulk 12  2450 non-null   float64
#  13  Bulk 13  18 non-null     float64
#  14  Bulk 14  2806 non-null   float64
#  15  Bulk 15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# ...

# %% [markdown]
# Данные о легирующих добавках. Пропуски надо заполнить нулями. Так же удалим все легирующий добавки, которые использовались в менее 1% случаев для упрощения модели.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# 👍 </div>

# %% [markdown]
# ###  Данные о подаче сыпучих материалов (время)

# %%
data_bulk_time.info()
data_bulk_time.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    object
#  2   Bulk 2   22 non-null     object
#  3   Bulk 3   1298 non-null   object
#  4   Bulk 4   1014 non-null   object
#  5   Bulk 5   77 non-null     object
#  6   Bulk 6   576 non-null    object
#  7   Bulk 7   25 non-null     object
#  8   Bulk 8   1 non-null      object
#  9   Bulk 9   19 non-null     object
#  10  Bulk 10  176 non-null    object
#  11  Bulk 11  177 non-null    object
#  12  Bulk 12  2450 non-null   object
#  13  Bulk 13  18 non-null     object
#  14  Bulk 14  2806 non-null   object
#  15  Bulk 15  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# ...

# %% [markdown]
# Данные о времени введения добавок на данный момент не несут ценности для предсказания

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# 👍 </div>

# %% [markdown]
# ### Данные о проволочных материалах (объём)

# %%
data_wire.info()
data_wire.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
#  7   Wire 7  11 non-null     float64
#  8   Wire 8  19 non-null     float64
#  9   Wire 9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# Данные о легирующих добавках. Пропуски надо заполнить нулями. Так же удалим все легирующий добавки, которые использовались в менее 1% случаев для упрощения модели.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# 👍 </div>

# %% [markdown]
# ### Данные о проволочных материалах (время)

# %%
data_wire_time.info()
data_wire_time.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:06:19                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:36:50                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:11:46                  NaN    NaN    NaN    NaN    NaN
# ...

# %% [markdown]
# Данные о времени введения добавок на данный момент не несут ценности для предсказания

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# 👍 </div>

# %% [markdown]
# ### Результаты измерения температуры

# %%
data_temp.info()
data_temp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   Время замера  18092 non-null  object
#  2   Температура   14665 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 424.2+ KB
#    key         Время замера  Температура
# 0    1  2019-05-03 11:02:04       1571.0
# 1    1  2019-05-03 11:07:18       1604.0
# 2    1  2019-05-03 11:11:34       1618.0
# 3    1  2019-05-03 11:18:04       1601.0
# 4    1  2019-05-03 11:25:59       1606.0

# %% [markdown]
# Не имеем возможность использовать данные об изменении температуры по ходу процесса, используем начальную температуру как признак, конечная и будет нашей целью предсказаний. Имеем возможность, однако, использовать время между первым и последним замером. Пропуски данных в этом случае недопустимы, необходимо удалить все парии с пропусками данных в измерении температуры.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# 👍 </div>

# %%
print('Всего строк:', data_temp['key'].count())
print('Число ключей:', data_temp['key'].value_counts().count())
data_temp['key'].value_counts().hist(bins=data_temp['key'].value_counts().max())

sns.histplot(x=data_temp['key'].value_counts(), bins=data_temp['key'].value_counts().max())
plt.xlabel('Число записей в ключе')
plt.ylabel('Число ключей')
plt.title('Разбивка ключей по числу записей температуры');
# Out:
# Всего строк: 18092
# Число ключей: 3216

# %% [markdown]
# Наблюдается стандартное отклонение. Не можем использовать партии, в которых есть только один замер. Таких партий немного, исключим их.

# %%
data_temp['Температура'].plot.box(vert=False)
plt.title('Разбивка записей по температуре');

# %% [markdown]
# Есть несколько выбросов температуры. Не можем доверять таким данным и придется выбросить все партии с такими выбросами

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - план v1 </b>
# Гораздо удобне разместить боксплот под гистограммой + повернуть на 90 градусов, чтобы оси совпадали.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#
# Это невозможно, так как на этих двух графиках я сравниваю разные значения
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v2 </b>
# ОК, но ведь в дополнение к боксплоту можно построить гистограмму с теми же данными </div>

# %% [markdown]
# ### Данные о продувке сплава газом

# %%
data_gas.info()
data_gas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
data_gas['Газ 1'].describe()
# Out:
# count    3239.000000
# mean       11.002062
# std         6.220327
# min         0.008399
# 25%         7.043089
# 50%         9.836267
# 75%        13.769915
# max        77.995040
# Name: Газ 1, dtype: float64

# %%
data_gas['Газ 1'].plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пропусков нет, выбивающиеся значения не выходят за рамки технологического процесса, проблем нет

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
# 👍 </div>

# %% [markdown]
# ### Вывод
# Данные рассмотрены. Найдены выбросы и пропуски для удаления при предобработке данных. Определены признаки предсказания: общая затраченная энергия, объем сыпучих и проволочных добавок, начальная температура и время нагрева, объем продувочного газа. Определены несущественные признаки которые не будут использоваться и не войдут в конечную таблицу данных. В конечной таблице для каждой парии будет соответствовать одна строка

# %% [markdown]
# Вопрос к заказчику: если мы не можем использовать температуры в ходе процесса для предсказания конечной температуры, то почему мы может использовать время нагрева от начальной до конечной температуры? Оно задано наперед? То же самое для данных по электродам. Мы можем использовать их для расчета общей энергии, хотя энергия вводится в ходе процесса исходя из времени и подающейся мощности. Эти параметры известны наперед?

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - план v1 </b>
# Я не нашел в твоем проекте раздела с вопросами к заказчику или сообщения, что вопросов нет</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#
# Добавил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v2 </b>
# Вопросы есть, ОК.
#
#
# По твоему вопросу: ТЗ заказчика это не запрещено. Видимо длительность процесса как и общее количество энергии (планируемые включения) мы можем оценить до начала плавки или уверенно предположить для моделирования процесса Хотя конечно этот фактор возможно нуждается в дополнительном исследовании после завершения проекта.
#
#
#
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - план v1 </b>
#
# Что  нужно понимать с выбросами. Бывают выбросы связанные с ошибками (например сбой датчика) и доверять таким данным нельзя.
#
# А бывают выбросы, являющиеся нормальной бизнес-практикой. И если мы их удалим, то конечно улучшим метрику, но наша модель будет не готова встретиться с реальными случаями, которые могут возникнуть в процессе работы.
#
# Поэтому используем следующую идею:
#
#  - Боксплот дает нам информацию к размышлению, но не руководство к действию.
#  - Исследуем явление. Могут ли такие данные быть в действительности?
#
# Например температура расплава 1200 не бывает, т.к. температура плавления стали 1450-1520. Не может быть отрицательной мощности.
#
# Поэтому супер-выбросы удаляем (удаляем не только одну запись, но данные по всей партии).
#
# А вот по остальным выбросам давай поступим таким образом: если решишь удалять (я бы не удалял), то делай это только на обучающем наборе. Тестовую выборку давай использовать честную.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий тимлида план v1</b>
#
# Давай подведем итоги.
# В целом с данным этапом ты справляешься. Данные исследованы, проведен графический анализ, есть план, <s>вопросы</s>.
#
# Пожалуйста проработай все красные комментарии.
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий тимлида план v2</b>
#
# С этим этапом закончили, переходим ко второму этапу</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - код v1 </b>
# Пожалуйста верни все наши комментарии из первой части проекта.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Вернул
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Данные об электродах

# %%
data_arc.columns = ['key', 'start', 'finish',
       'active', 'reactive']

# %% [markdown]
# Удалим партии с ошибочной реактивной мощностью

# %%
bad_keys = data_arc[data_arc['reactive'] < 0]['key'].unique()
data_arc = data_arc[~data_arc['key'].isin(bad_keys)]
data_arc['start'] = pd.to_datetime(data_arc['start'])
data_arc['finish'] = pd.to_datetime(data_arc['finish'])

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# Рассчитываем полную мощность и суммируем для каждой партии

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b></font>
#
# Так же число подач энергии, среднюю энергию и среднее время простоя
#
# </div>

# %%
data_arc['power'] = ((data_arc['active'] ** 2 + data_arc['reactive'] ** 2) ** 0.5 * 
                     (data_arc['finish'] - data_arc['start']).dt.total_seconds())
data_arc['downtime'] = (data_arc.groupby('key')['start'].shift(-1) - data_arc['finish']).dt.total_seconds()

data_arc = data_arc.groupby('key').agg(
    n_arc=('key', 'size'),
    power=('power', 'sum'),
    power_mean=('power', 'mean'),
#    downtime=('downtime', 'sum'), напрямую коррелирует с time_temp
    downtime_mean=('downtime', 'mean')
)
data_arc['downtime_mean'] = data_arc['downtime_mean'].fillna(0)

# %%
data_arc.info()
data_arc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3213 entries, 1 to 3241
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   n_arc          3213 non-null   int64
#  1   power          3213 non-null   float64
#  2   power_mean     3213 non-null   float64
#  3   downtime_mean  3213 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 125.5 KB
#      n_arc       power  power_mean  downtime_mean
# key
# 1        5  770.282114  154.056423     121.250000
# 2        4  481.760005  120.440001     111.000000
# 3        5  722.837668  144.567534     217.500000
# 4        4  683.455597  170.863899     117.333333
# 5        4  512.169934  128.042484     164.333333

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - код v1 </b>
# Пожалуйста покажи что получилось, не только несколько строк, но и размер итоговой таблички. </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b></font>
#
# Добавил новые признаки и верх таблицы
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# ### Данные о подаче сыпучих материалов

# %%
data_bulk.columns = data_bulk.columns.str.replace(' ','_').str.lower()

# %% [markdown]
# Удаляем все добавки, что вносились меньше одного процента раз и заполняем пропуски нулями

# %%
filtered_columns = data_bulk.columns[data_bulk.count() >= data_bulk['key'].max() * 0.01]
data_bulk = data_bulk[filtered_columns]
data_bulk = data_bulk.fillna(0)
data_bulk = data_bulk.set_index('key')

# %%
data_bulk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3129 entries, 1 to 3241
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   bulk_1   3129 non-null   float64
#  1   bulk_3   3129 non-null   float64
#  2   bulk_4   3129 non-null   float64
#  3   bulk_5   3129 non-null   float64
#  4   bulk_6   3129 non-null   float64
#  5   bulk_10  3129 non-null   float64
#  6   bulk_11  3129 non-null   float64
#  7   bulk_12  3129 non-null   float64
#  8   bulk_14  3129 non-null   float64
#  9   bulk_15  3129 non-null   float64
# dtypes: float64(10)
# memory usage: 268.9 KB

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# ### Данные о проволочных материалах

# %%
data_wire.columns = data_wire.columns.str.replace(' ','_').str.lower()

# %% [markdown]
# Удаляем все добавки, что вносились меньше одного процента раз и заполняем пропуски нулями

# %%
filtered_columns = data_wire.columns[data_wire.count() >= data_wire['key'].max() * 0.01]
data_wire = data_wire[filtered_columns]
data_wire = data_wire.fillna(0)
data_wire = data_wire.set_index('key')

# %%
data_wire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3081 entries, 1 to 3241
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   wire_1  3081 non-null   float64
#  1   wire_2  3081 non-null   float64
#  2   wire_3  3081 non-null   float64
#  3   wire_6  3081 non-null   float64
# dtypes: float64(4)
# memory usage: 120.4 KB

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# ### Результаты измерения температуры и газ

# %%
data_temp.columns = ['key', 'time', 'temperature']

# %% [markdown]
# Удаляем все партии, в которых есть пропуск измерений температуры

# %%
bad_keys = data_temp[data_temp['temperature'].isna()]['key'].unique()
data_temp = data_temp[~data_temp['key'].isin(bad_keys)]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# Удаляем все партии, в которых меньше двух записей измерения температуры

# %%
bad_keys = data_temp['key'].value_counts()
bad_keys = bad_keys[bad_keys < 2].index
data_temp = data_temp[~data_temp['key'].isin(bad_keys)]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
# Только в первой строке стоит найти название переменной получше </div>

# %% [markdown]
# Удаляем все партии, в которых измеренная температура слишком низка

# %%
bad_keys = data_temp[data_temp['temperature'] < 1400]['key'].unique()
data_temp = data_temp[~data_temp['key'].isin(bad_keys)]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %%
data_temp['time'] = pd.to_datetime(data_temp['time'])

# %% [markdown]
# Группируем данные

# %%
data_temp = data_temp.groupby('key').agg(
#    n_temp=('key', 'size'), напрямую коррелирует с n_arc
    first_temp=('temperature', 'first'),
    last_temp=('temperature', 'last'),
    time_temp=('time', lambda x: (x.max() - x.min()).total_seconds())
)

# %%
data_temp.info()
data_temp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2471 entries, 1 to 2499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_temp  2471 non-null   float64
#  1   last_temp   2471 non-null   float64
#  2   time_temp   2471 non-null   float64
# dtypes: float64(3)
# memory usage: 77.2 KB
#      first_temp  last_temp  time_temp
# key
# 1        1571.0     1613.0     1714.0
# 2        1581.0     1602.0     1265.0
# 3        1596.0     1599.0     1753.0
# 4        1601.0     1625.0     1220.0
# 5        1576.0     1602.0     1536.0

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v0</b>
#
# Не знаю как сделать лучше.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - код v1 </b>
# Мне кажется ты сильно все усложнил. Подскажу - в pandas есть агрегационные функции first и last.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Спасибо, изменил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# Данные о газе

# %%
data_gas.columns = ['key', 'gas']
data_gas = data_gas.set_index('key')

# %% [markdown]
# ### Объединение данных

# %%
data = ( data_bulk.merge(data_wire, how='inner', left_index=True, right_index=True)
                 .merge(data_arc, how='inner', left_index=True, right_index=True)
                 .merge(data_gas, how='inner', left_index=True, right_index=True)
                 .merge(data_temp, how='inner', left_index=True, right_index=True))

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - код v1 </b>
#
# Помнишь в Zen of Python - "явное лучше неявного". Дефолтные настройки слияния в merge - это inner. Но что-бы проверить это нужно лезть в докментацию. Лучше явно указать в аргументах `how='inner'` .
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Понял, изменил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# Данные собраны в одну таблицу, рассмотрим её

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2324 entries, 1 to 2499
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bulk_1         2324 non-null   float64
#  1   bulk_3         2324 non-null   float64
#  2   bulk_4         2324 non-null   float64
#  3   bulk_5         2324 non-null   float64
#  4   bulk_6         2324 non-null   float64
#  5   bulk_10        2324 non-null   float64
#  6   bulk_11        2324 non-null   float64
#  7   bulk_12        2324 non-null   float64
#  8   bulk_14        2324 non-null   float64
#  9   bulk_15        2324 non-null   float64
#  10  wire_1         2324 non-null   float64
#  11  wire_2         2324 non-null   float64
#  12  wire_3         2324 non-null   float64
#  13  wire_6         2324 non-null   float64
#  14  n_arc          2324 non-null   int64
#  15  power          2324 non-null   float64
#  16  power_mean     2324 non-null   float64
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(17, 17))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}).set(title='Корреляция параметров процесса')
for i in range(corr.shape[0]):
    for j in range(corr.shape[1]):
        if mask[i, j]:
            continue
        ax.text(j + 0.5, i + 0.5, f'{abs(corr.iloc[i, j]):.2f}',
                ha='center', va='center', color='black',
                bbox=dict(facecolor='white', edgecolor='white', boxstyle='round'))

ax.set_title('Correlation')
plt.show()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - код v1 </b>
#
# Но добавление чисел на хитмэп может улучшить понимание данных. Хотя главный результат виден и сейчас - сильных корреляций нет</div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Мне кажется с таким количеством ячеек, лучше ограничиться цветом. Нам не обязательны точные значения, когда мы просто поверхностно оцениваем зависимости.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>  Но когда тебе нужно понять, исключать ли признаки (например по границе 0,9) то точные цифры необходимы </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Там была ошибка в коде и визуально выше 0.3 корреляция не поднималась. Исправил и заодно добавил числа
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Корреляции разнятся в районе -0.3/0.3, что не очень много. Сильнее всего температура в конце процесса зависит от температуры в начале процесса, энергии процесса и добавок сыпучих 12, 15 и проволочных 1, 2. Более углубленно рассмотрим зависимости после обучения моделей

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Разделение тестовой выборки

# %%
features = data.drop('last_temp', axis=1)
target = data['last_temp']
features_train, features_test, target_train, target_test = train_test_split(features, 
                                                                            target, test_size=0.25,
                                                                                         random_state=STATE)
scaler = StandardScaler()
scaler.fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# ### Обучение моделей

# %%
models = pd.DataFrame({'model': [],'mae': []})

# %% [markdown]
# #### DummyRegressor

# %%
model_dr = DummyRegressor()
model_dr.fit(features_train, target_train)

mae = round(-cross_val_score(model_dr, features_train, target_train, 
                             scoring='neg_mean_absolute_error', cv=5).mean(), 3)
print('MAE нулевой модели:', mae)

models = models.append({'model': 'DummyRegressor','mae': mae}, ignore_index=True)
# Out:
# MAE нулевой модели: 7.882

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
# ОК, есть бейзлайн </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - код v1 </b>
# Использование кросс-валидации это обязательное условие проекта. Если гиперпараметры не подбираются используй cross_val_score()</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Добавил кросс-валидацию
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# #### LinearRegression

# %% [markdown]
# Так как у данной и следующей модели нет влиятельных параметров, кросс валидацию проводить не вижу смысла

# %%
model_lr = LinearRegression()
model_lr.fit(features_train, target_train)

mae = round(-cross_val_score(model_lr, features_train, target_train, 
                             scoring='neg_mean_absolute_error', cv=5).mean(), 3)
print('MAE линейной регрессии:', mae)

models = models.append({'model': 'LinearRegression','mae': mae}, ignore_index=True)
# Out:
# MAE линейной регрессии: 6.368

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - код v1 </b>
# Использование кросс-валидации это обязательное условие проекта. Если гиперпараметры не подбираются используй cross_val_score()</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Добавил кросс-валидацию
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger"><b> комментарий тимлида - код v1 </b>
# Логистическая регрессия это модель для решения задачи классификации, а мы решаем задачу регрессии</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Удалил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
#  👍 </div>

# %% [markdown]
# #### RandomForestRegressor

# %%
model_rf = RandomForestRegressor(random_state=STATE)
parameters = {

            
          'max_depth': np.arange(3,20,1),
          'n_estimators': np.arange(10,200,1)
    }
RSCV_rf = RandomizedSearchCV(model_rf,parameters,scoring='neg_mean_absolute_error',
                             cv=5,n_iter=10,verbose=2, random_state=STATE)

# %%
RSCV_rf.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END .....................max_depth=10, n_estimators=150; total time=   3.3s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   2.9s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   3.0s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   2.5s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   2.9s
# [CV] END .....................max_depth=12, n_estimators=138; total time=   3.0s
# [CV] END .....................max_depth=12, n_estimators=138; total time=   2.7s
# [CV] END .....................max_depth=12, n_estimators=138; total time=   2.8s
# [CV] END .....................max_depth=12, n_estimators=138; total time=   3.0s
# [CV] END .....................max_depth=12, n_estimators=138; total time=   2.8s
# [CV] END .....................max_depth=11, n_estimators=144; total time=   3.0s
# ...

# %%
print(RSCV_rf.best_params_)

mae = round(-RSCV_rf.best_score_,3)
print('MAE случайного леса:', mae)
models = models.append({'model': 'RandomForestRegressor','mae': mae}, ignore_index=True)
# Out:
# {'n_estimators': 182, 'max_depth': 19}
# MAE случайного леса: 6.281

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# #### LGBMRegressor

# %%
model_lgb = lgb.LGBMRegressor(verbose=1, random_state=STATE)
parameters = {
    'max_depth': np.arange(6,14,1),
    'n_estimators': np.arange(10,200,1),
    "learning_rate": np.arange(0.05,0.25,0.01),
    }
RSCV_lgb = RandomizedSearchCV(model_lgb,parameters,scoring='neg_mean_absolute_error',
                             cv=5,n_iter=10,verbose=2, random_state=STATE)

# %%
RSCV_lgb.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000599 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2589
# [LightGBM] [Info] Number of data points in the train set: 1394, number of used features: 21
# [LightGBM] [Info] Start training from score 1593.086801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
print(RSCV_lgb.best_params_)

mae = round(-RSCV_lgb.best_score_,3)
print('MAE LGBMRegressor:', mae)
models = models.append({'model': 'LGBMRegressor','mae': mae}, ignore_index=True)
# Out:
# {'n_estimators': 97, 'max_depth': 8, 'learning_rate': 0.1}
# MAE LGBMRegressor: 6.184

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# #### CatBoostRegressor

# %%
model_cb = CatBoostRegressor(verbose=1, random_state=STATE)
parameters = {
    'depth': np.arange(6,14,1),
    'n_estimators': np.arange(10,200,1),
    "learning_rate": np.arange(0.05,0.25,0.01),
    }
RSCV_cb = RandomizedSearchCV(model_cb,parameters,scoring='neg_mean_absolute_error',
                             cv=5,n_iter=10,verbose=1, random_state=STATE)

# %%
RSCV_cb.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# 0:	learn: 10.5789221	total: 67.2ms	remaining: 11.5s
# 1:	learn: 10.2343321	total: 80.4ms	remaining: 6.84s
# 2:	learn: 9.9579464	total: 91.1ms	remaining: 5.13s
# 3:	learn: 9.6949922	total: 101ms	remaining: 4.25s
# 4:	learn: 9.4224795	total: 110ms	remaining: 3.68s
# 5:	learn: 9.1983602	total: 119ms	remaining: 3.3s
# 6:	learn: 9.0126607	total: 134ms	remaining: 3.17s
# 7:	learn: 8.8410510	total: 148ms	remaining: 3.02s
# 8:	learn: 8.6359847	total: 160ms	remaining: 2.9s
# 9:	learn: 8.4761194	total: 171ms	remaining: 2.78s
# 10:	learn: 8.3344429	total: 183ms	remaining: 2.68s
# 11:	learn: 8.1905493	total: 194ms	remaining: 2.59s
# 12:	learn: 8.0667615	total: 203ms	remaining: 2.49s
# 13:	learn: 7.9394306	total: 214ms	remaining: 2.41s
# 14:	learn: 7.8611968	total: 222ms	remaining: 2.32s
# 15:	learn: 7.7539603	total: 231ms	remaining: 2.25s
# 16:	learn: 7.6813492	total: 239ms	remaining: 2.18s
# ...

# %%
print(RSCV_cb.best_params_)

mae = round(-RSCV_cb.best_score_,3)
print('MAE CatBoostRegressor:', mae)
models = models.append({'model': 'CatBoostRegressor','mae': mae}, ignore_index=True)
# Out:
# {'n_estimators': 121, 'learning_rate': 0.13, 'depth': 9}
# MAE CatBoostRegressor: 6.23

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
#  👍 </div>

# %% [markdown]
# ### Оценка лучшей модели

# %% [markdown]
# LGBMRegressor показал лучший результат, рассмотрим важность параметров

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# После добавления новых признаков, изменилась лучшая модель
#
# </div>

# %% [markdown]
# #### Важность параметров

# %%
(
pd.Series(RSCV_lgb.best_estimator_.feature_importances_, index=features.columns)
    .sort_values(ascending=False)
    .plot.barh(title='Важность параметров модели catboost',figsize=(11, 9))
)
plt.xlabel('Среднее уменьшение примеси');
plt.show()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
# Есть важность признаков. </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning"><b> комментарий тимлида - код v1 </b>
#
# График получился не очень удобный. Самая главная информация - названия признаков в порядке убывания. И приходится крутить головой чтобы их прчитать. К тому же они как-то "съехали".  Рекомендую повернуть график на 90 градусов и уделить внимание читаемости.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b>
#
# Изменил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v2 </b>
# Только сортировку стоит сделать в обратную сторону, от самых важных к самым неважным </div>

# %% [markdown]
# Самыми важными параметрами стали начальная температура и время между начальным и конечным изменением температуры

# %% [markdown]
# #### Проверка на тестовой выборке

# %%
pred_cb = RSCV_lgb.predict(features_test)
print('MAE на тестовой выборке:', round(mean_absolute_error(target_test, pred_cb),3))
# Out:
# MAE на тестовой выборке: 6.661

# %% [markdown]
# MAE 6.661, что меньше минимально требуемого. Задача выполнена

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
# Поздравляю с достижением целевой метрики.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v0</b></font>
#
# Готов принять комментарии и предложения к улучшению метрики.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
# Здесь работает простой принцип - на качество модели в первую очередь влияют признаки. Поэтому попробуй поэкспериментировать с их созданием. Только следи чтобы не было утечек (нельзя использовать промежуточные значения температуры).</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#    <b>комментарий студента - код v1</b></font>
#
# Добавил несколько значений ещё: количество измерений в партии, среднюю энергию и среднее время простоя, но точность не изменилась. Даже ухудшилась немного, с 6.654 до 6.661
#
# </div>

# %% [markdown]
# ### Вывод

# %%
models.sort_values('mae')
# Out:
#                    model    mae
# 3          LGBMRegressor  6.184
# 4      CatBoostRegressor  6.230
# 2  RandomForestRegressor  6.281
# 1       LinearRegression  6.368
# 0         DummyRegressor  7.882

# %% [markdown]
# Достигнута цель построить модель с MAE меньше 6.8, модель может быть применена для предсказания технологического параметра температуры ковша в конце процесса. Было построено 4 модели. Все модели адекватны, лучшей стал LGBMRegressor. Самыми влиятельными характеристиками стали начальная температура и время между начальным и конечным изменением температуры. Далее следует отчет с подробным описанием проведенного анализа

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - код v1 </b>
# ОК, есть вывод.</div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий тимлида код v1</b>
#
# Давай подведем итоги.
# В целом с данным этапом ты справился. Получены признаки, обучены модели. Самое главное - получена проходная итоговая метрика.
#
# Меня немного расстроило использование валидационной выборки вместо кросс-валидации, а также использование модели логистической регрессии. Но думаю это было из за волнения ))
#
# Нужно проработать красные комментарии, желтые уже на твое усмотрение.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий тимлида код v2</b>
#
# Все отлично, вижу что ты учел все мои замечания. Данный этап завершили, переходим к отчету.
#
#    Рекомендую стуктуру отчета строить исходя из вопросов, которые я подсветил на семинаре:
#
#   - сравнение решения и плана, если есть отклонение - объясняем почему
#   - описание трудностей проекта (и как они были решены)
#   - описание ключевых шагов решения
#       - подготовка данных (склейка, предобработка)
#       - обучение моделей, выбор лучшей и её тестирование
#   - признаки, которые использовали для обучения и их  предобработка
#   - полное описание модели (с гиперпараметрами, включая random_state, если использовался)
#   - итоговая метрика
#   - рекомендации по улучшению решения
#
#
#
#
# </div>

# %% [markdown]
# ## Отчет

# %% [markdown]
# План проекта включил 4 основные пункта: исследование данных, предподготовка данных, построение моделей с выбором лучшей, написание отчета. Таким образом, данный отчет завершает работу над проектом и сигнализирует выполенение всех целей плана.
#
# Основным лимитирующим фактором в проекте можно назвать ограниченую функциональность сетевой версии Jupyter Notebook, пришлось занижать итерации и границы гиперпараметров RandomizedSearchCV, что напрямую снизило метрику качества конечной модели.
#
# Исследование данных проводилось методами .info(), .head(), histplot() и boxplot(). Основные цели: поиска выбросов и ошибок, оценка данных для дальнейшего разделения на признаки.
#
# Предобработка данных включила несколько операций. Переименование столбцов таблиц в змеиный регистр. Было поведено удаление грубых выбросов для данных об электродах и измерении температуры. В данных об измерении температуры потребовалось отбросить партии, в которых не было различия между начальным и конечным измереним температуры. Так же пришлось удалить партии, в которых находились пропуски измерения температуры. В конце обработки, данные из разных таблиц были объединены внутренним соединением в одну для отправки на обучение модели. Всего из ~3239 партий обработку прошло 2324.
#
# Для обучения модели, в начале была отобрана 25% тестовая выборка. На обучающей выборке было построено 4 модели: линейная регрессия, случайный лес, LGBM и CatBoost, с использованием cross_val_score для линейной регрессии и RandomizedSearchCV для остальных. Все модели показали адекватность в сравнении с нулевой моделью. Лучшая модель отбиралась по общему показателю качества - средней абсолютной ошибке и после тестировалась на тестовой выборке для получения конечного значения.
#
# Из данных по электроду было получено 4 признака: число циклов, общая затраченная энергия, средняя затраченная энергия и среднее время простоя. Общее время простоя не использовалось, так как оно напряую коррелировало с временем между первым и последним измерением температуры. Затраченная энергия рассчитывалась агрегацией по полной мощности, полученной из активной и реактивной мощности, и временем нагрева дуги. Время простоя получено агрегацией времени между концом и началом наргева дуги двух последовательных циклов.
#
# Из данных о добавках были исключены все, что были использованы в менее 1% партий. Можно увидеть зависимость, что даже в этом случае, наименее используемые добавки оказались внизу списка важности признаков для модели. Таким образом не стоит ожидать сильного понижения ошибки модели, при внесении их в обучающие признаки.
#
# Из данных измерения температуры получено 2 признака: начальная температура и время между измерением начальной и конечной температуры. Промежуточные температуры заранее неизвестны и не применялись. Конечная температура стала нашей целью предсказаний.
#
# Данных о продувке сплава газом использовались без изменений как один признак.
#
# Лучшей моделью стал LGBM с гиперпараметрами: 'n_estimators': 97, 'max_depth': 8, 'learning_rate': 0.1, 'random_state': 140823. Эту модель нельзя назвать неоспоримым лидером, так как CatBoost отстал на минимальное расстояние. Их различие связано с методикой случайного подбора гиперпараметров методом RandomizedSearchCV, катерогически сказать какая из моделей лучше нельзя. При дальнейшей работе над улучшением предсказаний, следует сравнивать обе модели. Самыми влиятельными характеристиками стали начальная температура и время между начальным и конечным изменением температуры. Итоговая метрика MAE на тестовой выборке составила 6.661, что ниже минимальной 6.8.
#
# Ошибкой предобработки было внутренее соединение в общие данные данных о добавках и продувке газом. Отсутствие этих данных для любой данной партий не будет означать, что эту партию использовать нельзя, такие пропуски следовало заполнить нулями. Это подтверждается отсутствием значений, равных нулю в этих данных. Они не были внесены в таблицу.
#
# Для дальнейшего улучшения метрики, можно предложить следующие методы:
# 1. Внесение других гиперпараметров в переменные модели CatBoost/LGBM
# 2. Расширение границ рассматриваемых гиперпараметров
# 3. Увеличение количества итераций для поиска лучшей комбинации RandomizedSearchCV
# 4. Рассмотреть замену RandomizedSearchCV на HalvingRandomSearchCV, который обещает ускоренный поиск лучших параметров
# 5. Пересмотр исходных данных с целью поиска не обнаруженных ранее полезных признаков

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success"><b> комментарий тимлида - отчет v1 </b>
#  👍 У тебя получился интересный отчет, я нашел в нем ответы на все вопросы, заданные во время вводного созвона.
#
#
#
# ✨ Поздравляю тебя с успешным завершением финального спринта! Если вспомнить, с чего начиналось обучение, видно как от простых задач мы перешли к реальным проектам, и у тебя это здорово получилось 👍
#
# ***
# Сейчас ты можешь доработать этот проект с учетом рекомендаций, удалить наши с тобой комментарии и добавить себе в портфолио — лучше это сделать в ближайшее время, пока все нюансы еще отложились в памяти =)
#
# ***
#
# Далее, хочу добавить некоторые ссылки на полезные ресурсы по машинному обучению:
#
# https://academy.yandex.ru/handbook/ml онлайн-учебник от Школы анализа данных Яндекса, в котором описаны теоретические основы работы моделей машинного обучения;
#
# https://www.youtube.com/watch?v=xl1fwCza9C8 познавательное видео по настройке модели CatBoost
#
# https://habr.com/ru/company/ods/blog/322626/ на Habr можно закрепить свои знания, порешав задачи из цикла статей — Открытый курс машинного обучения
#
# https://github.com/esokolov/ml-course-hse — на гитхаб есть репозиторий с задачами из курса по машинному обучению от Евгения Соколова, можно использовать как дополнительный материал для закрепления знаний.
#
# https://habr.com/ru/company/avito/blog/571094/ — материалы по A/B тестам.
#
# В некоторых компаниях при устройстве на работу или стажировку, например в Яндексе, нужно решить тест на алгоритмические задачи. По алгоритмам есть много разных курсов, платных и бесплатных. Можно попробовать Тренировки по Алгоритмам от Яндекса https://yandex.ru/yaintern/algorithm-training (бесплатно, хороший курс). Насколько знаю, у Практикума тоже есть курс по алгоритмам.
#
# ***
# Если тебе понравились нейронки, то вот несколько интересных курсов:
#
#    - "Дип Лернинг на пальцах" (https://www.youtube.com/playlist?list=PL5FkQ0AF9O_o2Eb5Qn8pwCDg7TniyV1Wb).
#    - Отличный бесплатный курс от Школы глубокого обучения МФТИ (https://stepik.org/org/dlschool), старт курса каждые пол года. Два семестра, один по основам и компьютерному зрению, второй по обработке естественного языка. Проходить нужно именно в таком порядке,т.к. почти весь современный NLP построен на нейронках.
#
#    - "Нейронные сети и компьютерное зрение" от Samsung Research Russia (https://stepik.org/course/50352/syllabus). Есть также продолжение по NLP.
#    - Трек NLP от сообщества ODS https://ods.ai/tracks/nlp-course-autumn-22
#
#
# ***
#
# Также для будущей работы стоит прокачать следующие знания/навыки:
# Docker для контейниризации твоих моделей с целью дальнейшего встраивания в продакшн. Кстати, вот отличное видео https://www.youtube.com/watch?v=QF4ZF857m44
#
# Также стоит не забыать прокачивать навыки в SQL.
#
# После окончания финального спринта у нас будет заключительная консультация, где мы сможем подвести итоги.
#
# Отчет принимаю и до встречи!
#
# </div>
